# %%
import os
import pandas as pd
import time
import webbrowser

# %%
query = pd.read_csv('./query csv/LAADS_query.2025-11-07T13_49.csv')

# %%
query
# Out:
#          fileId  \
# 0    8696130896
# 1    8696128031
# 2    8679161481
# 3    8677505916
# 4    8652846088
# ..          ...
# 187  5877249962
# 188  5837949745
# 189  5837949746
# 190  5836823164
# 191  5836823798
#
#     fileUrls from query MOD13A2--61 2020-12-10..2025-01-20 x35.5y32.2 x37.4y31[7]  \
# 0    https://ladsweb.modaps.eosdis.nasa.gov/api/v2/...
# 1    https://ladsweb.modaps.eosdis.nasa.gov/api/v2/...
# 2    https://ladsweb.modaps.eosdis.nasa.gov/api/v2/...
# 3    https://ladsweb.modaps.eosdis.nasa.gov/api/v2/...
# 4    https://ladsweb.modaps.eosdis.nasa.gov/api/v2/...
# ..                                                 ...
# 187  https://ladsweb.modaps.eosdis.nasa.gov/api/v2/...
# 188  https://ladsweb.modaps.eosdis.nasa.gov/api/v2/...
# 189  https://ladsweb.modaps.eosdis.nasa.gov/api/v2/...
# 190  https://ladsweb.modaps.eosdis.nasa.gov/api/v2/...
# 191  https://ladsweb.modaps.eosdis.nasa.gov/api/v2/...
#
#          size
# 0    21665937
# 1    12295093
# ...

# %%
query.columns[1]
# Out:
# 'fileUrls from query MOD13A2--61 2020-12-10..2025-01-20 x35.5y32.2 x37.4y31[7]'

# %%
col = query.columns[1]
for i in range(len(query)):
    url = query[col][i]
    webbrowser.open(url)
    time.sleep(1)
    if (i+1) % 5 == 0:
        time.sleep(20)
    if (i+1) % 50 == 0:
        time.sleep(20)
